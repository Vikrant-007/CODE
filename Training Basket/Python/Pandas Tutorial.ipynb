# %% [markdown]
# ## Author - Prem kumar bharti
# # Pandas tutorial

# %% [markdown]
# * it is a powerful python data analysis toolkit
# * A fast and efficient Dataframe object for data manipulation
# * we can read and write : csv , txt , xml , json , zip etc

# %%
import pandas as pd

# %% [markdown]
# ## Read files

# %%
df1 = pd.read_csv("titanic.csv")
df1
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# 0      man        True  NaN  Southampton    no  False
# 1    woman       False    C    Cherbourg   yes  False
# 2    woman       False  NaN  Southampton   yes   True
# 3    woman       False    C  Southampton   yes  False
# 4      man        True  NaN  Southampton    no   True
# ..     ...         ...  ...          ...   ...    ...
# 886    man        True  NaN  Southampton    no   True
# 887  woman       False    B  Southampton   yes   True
# 888  woman       False  NaN  Southampton    no  False
# 889    man        True    C    Cherbourg   yes   True
# 890    man        True  NaN   Queenstown    no   True
#
# [891 rows x 15 columns]

# %% [markdown]
# ## isnull()

# %%
df1.isnull().sum() ## it will find missing values in columns
# Out:
# survived         0
# pclass           0
# sex              0
# age            177
# sibsp            0
# parch            0
# fare             0
# embarked         2
# class            0
# who              0
# adult_male       0
# deck           688
# embark_town      2
# alive            0
# alone            0
# dtype: int64

# %% [markdown]
# ## Dropna

# %%
df1 = df1.dropna() ## drop rows in which we have missing values

# %% [markdown]
# ## Fillna()

# %%
df1 = pd.read_csv("titanic.csv")

# %%
df1["deck"].fillna("kiran" , inplace=True)

# %%
df1[["deck", "age"]] = df1[["deck", "age"]].fillna("ab")
df1.head(10)
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0         0       3    male  22.0      1      0   7.2500        S   Third
# 1         1       1  female  38.0      1      0  71.2833        C   First
# 2         1       3  female  26.0      0      0   7.9250        S   Third
# 3         1       1  female  35.0      1      0  53.1000        S   First
# 4         0       3    male  35.0      0      0   8.0500        S   Third
# 5         0       3    male    ab      0      0   8.4583        Q   Third
# 6         0       1    male  54.0      0      0  51.8625        S   First
# 7         0       3    male   2.0      3      1  21.0750        S   Third
# 8         1       3  female  27.0      0      2  11.1333        S   Third
# 9         1       2  female  14.0      1      0  30.0708        C  Second
#
#      who  adult_male   deck  embark_town alive  alone
# 0    man        True  kiran  Southampton    no  False
# 1  woman       False      C    Cherbourg   yes  False
# 2  woman       False  kiran  Southampton   yes   True
# 3  woman       False      C  Southampton   yes  False
# 4    man        True  kiran  Southampton    no   True
# 5    man        True  kiran   Queenstown    no   True
# 6    man        True      E  Southampton    no   True
# 7  child       False  kiran  Southampton    no  False
# 8  woman       False  kiran  Southampton   yes  False
# 9  child       False  kiran    Cherbourg   yes  False

# %% [markdown]
# ## ILoc

# %%
df2 = pd.read_csv("SalaryGender.csv")
print(df2)
# Out:
#     Salary  Gender  Age  PhD
# 0    140.0       1   47    1
# 1     30.0       0   65    1
# 2     35.1       0   56    0
# 3     30.0       1   23    0
# 4     80.0       0   53    1
# ..     ...     ...  ...  ...
# 95    18.6       1   26    0
# 96   152.0       1   56    1
# 97     1.8       1   28    0
# 98    35.0       0   44    0
# 99     4.0       0   24    0
#
# [100 rows x 4 columns]

# %%
df2.shape
# Out:
# (100, 4)

# %%
df2.iloc[2:5,1:3]
# Out:
#    Gender  Age
# 2       0   56
# 3       1   23
# 4       0   53

# %%
df2.iloc[:,:-1]
# Out:
#     Salary  Gender  Age
# 0    140.0       1   47
# 1     30.0       0   65
# 2     35.1       0   56
# 3     30.0       1   23
# 4     80.0       0   53
# ..     ...     ...  ...
# 95    18.6       1   26
# 96   152.0       1   56
# 97     1.8       1   28
# 98    35.0       0   44
# 99     4.0       0   24
#
# [100 rows x 3 columns]

# %%
df2.iloc[:,:]
# Out:
#     Salary  Gender  Age  PhD
# 0    140.0       1   47    1
# 1     30.0       0   65    1
# 2     35.1       0   56    0
# 3     30.0       1   23    0
# 4     80.0       0   53    1
# ..     ...     ...  ...  ...
# 95    18.6       1   26    0
# 96   152.0       1   56    1
# 97     1.8       1   28    0
# 98    35.0       0   44    0
# 99     4.0       0   24    0
#
# [100 rows x 4 columns]
